# %% [markdown]
# # Python for Public Transport
#
# by Alex Raichev
# for Kiwi PyCon 2019
# in Wellington, New Zealand

# %% [markdown]
# ## My background
#
# - Do like math, algorithms, and Python
# - Work at MRCagney in Auckland, a walking, cycling, public transport, and planning consultancy
# - Get to use Python there to analyze and visualize civic data

# %% [markdown]
# ## Intro
#
# - Three main kinds of public transport data:
#     * **Scheduling**: when and where the vehicles should be
#     * **Realtime**: when and where the vehicles actually are
#     * **Ticketing**: who is riding the vehicels
# - Focus here on **scheduling data**

# %% [markdown]
# ## General Transit Feed Specification (GTFS)
#
# - Most popular **open standard** for encoding scheduling data
# - Developed in 2005 by Portland's TriMet transit agency and Google
# - Some uses
#     * Routing, ala Google Maps
#     * Measuring performance
#     * Answering whimsical questions

# %% [markdown]
# ## Running Example
#
# - A recent GTFS feed for Wellington downloadable from [TransitFeeds](http://transitfeeds.com/p/metlink/22)
# - [Visit TransitFeeds and explore the feed to understand the spec]

# %% [markdown]
# ## Challenge
#
# Use the Wellington GTFS feed and Python to answer the following questions:
#
# - What is the most/least frequent route?
# - What is the shortest/longest distance route?
# - What is the slowest/fastest route?

# %% [markdown]
# ## Approach
#
# - Pythonistas, how to handle all those CSVs?
# - ``csv`` module?
# - Database?
# - Suggestions?

# %% [markdown]
# - [GTFSTK](https://github.com/mrcagney/gtfstk), an open source A Python 3.6+ tool kit for analyzing GTFS data
# - It's the best library for this sort of thing
# - Disclaimer: i wrote it

# %%
from pathlib import Path

import gtfstk as gt
import pandas as pd


DATA_DIR = Path("../data")
# %ls {DATA_DIR}

# Set study date
DATE = "20190408"  # Monday
# Out:
# wellington_gtfs_20190331.zip

# %%
# Read GTFS feed

feed = gt.read_gtfs(DATA_DIR/"wellington_gtfs_20190331.zip", dist_units="km")
feed.describe()
# Out:
#                            indicator  \
# 0                           agencies
# 1                           timezone
# 2                         start_date
# 3                           end_date
# 4                         num_routes
# 5                          num_trips
# 6                          num_stops
# 7                         num_shapes
# 8                        sample_date
# 9   num_routes_active_on_sample_date
# 10   num_trips_active_on_sample_date
# 11   num_stops_active_on_sample_date
#
#                                                 value
# 0   [Valley Flyer, Mana Coach Services Ltd, Metlin...
# 1                                    Pacific/Auckland
# 2                                            20190331
# 3                                            20191231
# 4                                                  98
# 5                                                8621
# 6                                                2884
# 7                                                 319
# 8                                            20190404
# 9                                                  86
# 10                                               4089
# 11                                               2844

# %%
# Validate

feed.validate()
# Out:
# /home/araichev/.virtualenvs/python_for_public_transport/lib/python3.6/site-packages/gtfstk/validators.py:1422: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   g = pd.concat([g, feed.calendar_dates])
#       type                                  message       table  \
# 1  warning  Repeated pair (trip_id, departure_time)  stop_times
# 0  warning                   Stop has no stop times       stops
# 2  warning         Unrecognized column from_trip_id   transfers
# 3  warning           Unrecognized column to_trip_id   transfers
#
#                                                 rows
# 1   [172594, 172663, 172732, 172801, 172870, 172939]
# 0  [2870, 2871, 2872, 2873, 2874, 2875, 2876, 287...
# 2                                                 []
# 3                                                 []

# %% [markdown]
# ## Pandas play

# %%
feed.trips.T
# Out:
#                                              0                           1     \
# route_id                                      320                         320
# service_id                                    229                         143
# trip_id                32x__0__103__TZM__229__229  32x__0__111__TZM__143__143
# trip_headsign                                 NaN                         NaN
# direction_id                                    0                           0
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]2         [@356.0.16077778@]2
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                              2                           3     \
# route_id                                      320                         320
# service_id                                    127                         137
# trip_id                32x__0__123__TZM__127__127  32x__0__119__TZM__137__137
# trip_headsign                                 NaN                         NaN
# direction_id                                    0                           0
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]2         [@356.0.16077778@]2
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                              4     \
# route_id                                      320
# service_id                                    102
# trip_id                32x__0__117__TZM__102__102
# trip_headsign                                 NaN
# direction_id                                    0
# block_id                                      NaN
# shape_id                      [@356.0.16077778@]2
# wheelchair_accessible                         NaN
# bikes_allowed                                   2
#
#                                                    5     \
# route_id                                            320
# service_id                                        159_2
# trip_id                32x__0__115__TZM__159__2__159__2
# trip_headsign                                       NaN
# direction_id                                          0
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]2
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                    6     \
# route_id                                            320
# service_id                                        217_1
# trip_id                32x__0__107__TZM__217__1__217__1
# trip_headsign                                       NaN
# direction_id                                          0
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]2
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                              7                           8     \
# route_id                                      320                         320
# service_id                                    241                         218
# trip_id                32x__0__101__TZM__241__241  32x__0__121__TZM__218__218
# trip_headsign                                 NaN                         NaN
# direction_id                                    0                           0
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]2         [@356.0.16077778@]2
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                              9     \
# route_id                                      320
# service_id                                    139
# trip_id                32x__0__109__TZM__139__139
# trip_headsign                                 NaN
# direction_id                                    0
# block_id                                      NaN
# shape_id                      [@356.0.16077778@]2
# wheelchair_accessible                         NaN
# bikes_allowed                                   2
#
#                                     ...                \
# route_id                            ...
# service_id                          ...
# trip_id                             ...
# trip_headsign                       ...
# direction_id                        ...
# block_id                            ...
# shape_id                            ...
# wheelchair_accessible               ...
# bikes_allowed                       ...
#
#                                                       8611  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__1__9323__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8612  \
# route_id                                                 6
# service_id                                         Rail Sa
# trip_id                        JVL__1__9367__RAIL__Rail_Sa
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8613  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__0__9358__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8614  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__0__9328__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                 8615  \
# route_id                                         140
# service_id                              MTuWThF-XSch
# trip_id                14__1__198__NBM__MTuWThF-XSch
# trip_headsign                                    NaN
# direction_id                                       1
# block_id                                         NaN
# shape_id                         [@356.0.30312352@]5
# wheelchair_accessible                            NaN
# bikes_allowed                                      2
#
#                                                 8616  \
# route_id                                         140
# service_id                              MTuWThF-XSch
# trip_id                14__0__201__NBM__MTuWThF-XSch
# trip_headsign                                    NaN
# direction_id                                       0
# block_id                                         NaN
# shape_id                         [@356.0.30312352@]2
# wheelchair_accessible                            NaN
# bikes_allowed                                      2
#
#                                                        8617  \
# route_id                                                830
# service_id                                     MTuWThF-XSch
# trip_id                       83__0__161__NBM__MTuWThF-XSch
# trip_headsign                                           NaN
# direction_id                                              0
# block_id                                                NaN
# shape_id               [@356.0.30313467@]83:382#12651#12715
# wheelchair_accessible                                   NaN
# bikes_allowed                                             2
#
#                                                        8618  \
# route_id                                                830
# service_id                                     MTuWThF-XSch
# trip_id                       83__0__159__NBM__MTuWThF-XSch
# trip_headsign                                           NaN
# direction_id                                              0
# block_id                                                NaN
# shape_id               [@356.0.30313467@]83:382#12651#12715
# wheelchair_accessible                                   NaN
# bikes_allowed                                             2
#
#                                                  8619  \
# route_id                                         1210
# service_id                               MTuWThF-XSch
# trip_id                121__0__145__TZM__MTuWThF-XSch
# trip_headsign                                     NaN
# direction_id                                        0
# block_id                                          NaN
# shape_id                          [@356.0.42934812@]1
# wheelchair_accessible                             NaN
# bikes_allowed                                       2
#
#                                                  8620
# route_id                                         1210
# service_id                               MTuWThF-XSch
# trip_id                121__1__142__TZM__MTuWThF-XSch
# trip_headsign                                     NaN
# direction_id                                        1
# block_id                                          NaN
# shape_id                          [@356.0.42934812@]2
# wheelchair_accessible                             NaN
# bikes_allowed                                       2
#
# [9 rows x 8621 columns]

# %%
# Only show route, trip, and shape columns: slice columns, AKA filter
feed.trips.filter(["route_id", "trip_id", "shape_id"]).T
# Out:
#                                 0                           1     \
# route_id                         320                         320
# trip_id   32x__0__103__TZM__229__229  32x__0__111__TZM__143__143
# shape_id         [@356.0.16077778@]2         [@356.0.16077778@]2
#
#                                 2                           3     \
# route_id                         320                         320
# trip_id   32x__0__123__TZM__127__127  32x__0__119__TZM__137__137
# shape_id         [@356.0.16077778@]2         [@356.0.16077778@]2
#
#                                 4                                 5     \
# route_id                         320                               320
# trip_id   32x__0__117__TZM__102__102  32x__0__115__TZM__159__2__159__2
# shape_id         [@356.0.16077778@]2               [@356.0.16077778@]2
#
#                                       6                           7     \
# route_id                               320                         320
# trip_id   32x__0__107__TZM__217__1__217__1  32x__0__101__TZM__241__241
# shape_id               [@356.0.16077778@]2         [@356.0.16077778@]2
#
#                                 8                           9     \
# route_id                         320                         320
# trip_id   32x__0__121__TZM__218__218  32x__0__109__TZM__139__139
# shape_id         [@356.0.16077778@]2         [@356.0.16077778@]2
#
#                        ...                                               8611  \
# route_id               ...                                                  6
# trip_id                ...                         JVL__1__9323__RAIL__Su+Hol
# shape_id               ...                [@6.0.20608239@]JVL:801#24315#24322
#
#                                          8612  \
# route_id                                    6
# trip_id           JVL__1__9367__RAIL__Rail_Sa
# shape_id  [@6.0.20608239@]JVL:801#24315#24322
#
#                                          8613  \
# route_id                                    6
# trip_id            JVL__0__9358__RAIL__Su+Hol
# shape_id  [@6.0.20608239@]JVL:803#24333#24340
#
#                                          8614                           8615  \
# route_id                                    6                            140
# trip_id            JVL__0__9328__RAIL__Su+Hol  14__1__198__NBM__MTuWThF-XSch
# shape_id  [@6.0.20608239@]JVL:803#24333#24340            [@356.0.30312352@]5
#
#                                    8616                                  8617  \
# route_id                            140                                   830
# trip_id   14__0__201__NBM__MTuWThF-XSch         83__0__161__NBM__MTuWThF-XSch
# shape_id            [@356.0.30312352@]2  [@356.0.30313467@]83:382#12651#12715
#
#                                           8618  \
# route_id                                   830
# trip_id          83__0__159__NBM__MTuWThF-XSch
# shape_id  [@356.0.30313467@]83:382#12651#12715
#
#                                     8619                            8620
# route_id                            1210                            1210
# trip_id   121__0__145__TZM__MTuWThF-XSch  121__1__142__TZM__MTuWThF-XSch
# shape_id             [@356.0.42934812@]1             [@356.0.42934812@]2
#
# [3 rows x 8621 columns]

# %%
# Find all trips of a specific route: slice rows
feed.trips.loc[lambda x: x.route_id == "6"].T
# Out:
#                                                       8399  \
# route_id                                                 6
# service_id                                         Rail Sa
# trip_id                        JVL__1__9331__RAIL__Rail_Sa
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                         8400  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__1__9225__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               1
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                         8401  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__0__9250__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               0
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                       8402  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__0__9326__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                         8403  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__1__9263__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               1
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                       8404  \
# route_id                                                 6
# service_id                                         Rail Sa
# trip_id                        JVL__0__9336__RAIL__Rail_Sa
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8405  \
# route_id                                                 6
# service_id                                         Rail Sa
# trip_id                        JVL__0__9392__RAIL__Rail_Sa
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8406  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__1__9367__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8407  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__1__9355__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8408  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__1__9333__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                       ...                   \
# route_id                              ...
# service_id                            ...
# trip_id                               ...
# trip_headsign                         ...
# direction_id                          ...
# block_id                              ...
# shape_id                              ...
# wheelchair_accessible                 ...
# bikes_allowed                         ...
#
#                                                         8605  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__1__9221__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               1
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                       8606  \
# route_id                                                 6
# service_id                                         Rail Sa
# trip_id                        JVL__0__9362__RAIL__Rail_Sa
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                         8607  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__0__9222__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               0
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                         8608  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__0__9232__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               0
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                         8609  \
# route_id                                                   6
# service_id                                 Rail MTuWThF-XHol
# trip_id                JVL__0__9256__RAIL__Rail_MTuWThF-XHol
# trip_headsign                                            NaN
# direction_id                                               0
# block_id                                                 NaN
# shape_id                 [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                    NaN
# bikes_allowed                                              2
#
#                                                       8610  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__1__9381__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8611  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__1__9323__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8612  \
# route_id                                                 6
# service_id                                         Rail Sa
# trip_id                        JVL__1__9367__RAIL__Rail_Sa
# trip_headsign                                          NaN
# direction_id                                             1
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:801#24315#24322
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8613  \
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__0__9358__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
#                                                       8614
# route_id                                                 6
# service_id                                          Su+Hol
# trip_id                         JVL__0__9328__RAIL__Su+Hol
# trip_headsign                                          NaN
# direction_id                                             0
# block_id                                               NaN
# shape_id               [@6.0.20608239@]JVL:803#24333#24340
# wheelchair_accessible                                  NaN
# bikes_allowed                                            2
#
# [9 rows x 216 columns]

# %%
# Group all trips by route: group
feed.trips.groupby("route_id").get_group("320").T
# Out:
#                                                0                           1   \
# route_id                                      320                         320
# service_id                                    229                         143
# trip_id                32x__0__103__TZM__229__229  32x__0__111__TZM__143__143
# trip_headsign                                 NaN                         NaN
# direction_id                                    0                           0
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]2         [@356.0.16077778@]2
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                                2                           3   \
# route_id                                      320                         320
# service_id                                    127                         137
# trip_id                32x__0__123__TZM__127__127  32x__0__119__TZM__137__137
# trip_headsign                                 NaN                         NaN
# direction_id                                    0                           0
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]2         [@356.0.16077778@]2
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                                4   \
# route_id                                      320
# service_id                                    102
# trip_id                32x__0__117__TZM__102__102
# trip_headsign                                 NaN
# direction_id                                    0
# block_id                                      NaN
# shape_id                      [@356.0.16077778@]2
# wheelchair_accessible                         NaN
# bikes_allowed                                   2
#
#                                                      5   \
# route_id                                            320
# service_id                                        159_2
# trip_id                32x__0__115__TZM__159__2__159__2
# trip_headsign                                       NaN
# direction_id                                          0
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]2
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                      6   \
# route_id                                            320
# service_id                                        217_1
# trip_id                32x__0__107__TZM__217__1__217__1
# trip_headsign                                       NaN
# direction_id                                          0
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]2
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                7                           8   \
# route_id                                      320                         320
# service_id                                    241                         218
# trip_id                32x__0__101__TZM__241__241  32x__0__121__TZM__218__218
# trip_headsign                                 NaN                         NaN
# direction_id                                    0                           0
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]2         [@356.0.16077778@]2
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                                9              ...              \
# route_id                                      320             ...
# service_id                                    139             ...
# trip_id                32x__0__109__TZM__139__139             ...
# trip_headsign                                 NaN             ...
# direction_id                                    0             ...
# block_id                                      NaN             ...
# shape_id                      [@356.0.16077778@]2             ...
# wheelchair_accessible                         NaN             ...
# bikes_allowed                                   2             ...
#
#                                                14                          15  \
# route_id                                      320                         320
# service_id                                    148                         131
# trip_id                32x__1__112__TZM__148__148  32x__1__104__TZM__131__131
# trip_headsign                                 NaN                         NaN
# direction_id                                    1                           1
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]1         [@356.0.16077778@]1
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
#                                                      16  \
# route_id                                            320
# service_id                                        160_1
# trip_id                32x__1__120__TZM__160__1__160__1
# trip_headsign                                       NaN
# direction_id                                          1
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]1
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                      17  \
# route_id                                            320
# service_id                                        204_2
# trip_id                32x__1__106__TZM__204__2__204__2
# trip_headsign                                       NaN
# direction_id                                          1
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]1
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                      18  \
# route_id                                            320
# service_id                                        201_1
# trip_id                32x__1__102__TZM__201__1__201__1
# trip_headsign                                       NaN
# direction_id                                          1
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]1
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                19  \
# route_id                                      320
# service_id                                    218
# trip_id                32x__1__118__TZM__218__218
# trip_headsign                                 NaN
# direction_id                                    1
# block_id                                      NaN
# shape_id                      [@356.0.16077778@]1
# wheelchair_accessible                         NaN
# bikes_allowed                                   2
#
#                                                      20  \
# route_id                                            320
# service_id                                        216_1
# trip_id                32x__1__116__TZM__216__1__216__1
# trip_headsign                                       NaN
# direction_id                                          1
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]1
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                      21  \
# route_id                                            320
# service_id                                        101_2
# trip_id                32x__1__114__TZM__101__2__101__2
# trip_headsign                                       NaN
# direction_id                                          1
# block_id                                            NaN
# shape_id                            [@356.0.16077778@]1
# wheelchair_accessible                               NaN
# bikes_allowed                                         2
#
#                                                22                          23
# route_id                                      320                         320
# service_id                                    137                         140
# trip_id                32x__1__108__TZM__137__137  32x__1__110__TZM__140__140
# trip_headsign                                 NaN                         NaN
# direction_id                                    1                           1
# block_id                                      NaN                         NaN
# shape_id                      [@356.0.16077778@]1         [@356.0.16077778@]1
# wheelchair_accessible                         NaN                         NaN
# bikes_allowed                                   2                           2
#
# [9 rows x 24 columns]

# %%
# Compute number of trips per route: split, apply, combine
def my_agg(group):
    d = {}
    d["num_trips"] = group.shape[0]
    return pd.Series(d)

# Use method chaining
(
    feed.trips
    # Split
    .groupby("route_id")
    # Apply and combine
    .apply(my_agg)
    .reset_index()
    # Join in route short name from feed.routes
    .merge(feed.routes.filter(["route_id", "route_short_name", "route_long_name", "route_type"]))
    # Sort
    .sort_values("num_trips", ascending=False)
    .T
)
# Out:
#                                                 87  \
# route_id                                         9
# num_trips                                      498
# route_short_name                               CCL
# route_long_name   Cable Car (Kelburn - Wellington)
# route_type                                       5
#
#                                                                  0   \
# route_id                                                         10
# num_trips                                                       424
# route_short_name                                                  1
# route_long_name   Johnsonville West/Churton Park/Grenada Village...
# route_type                                                        3
#
#                                                                  62  \
# route_id                                                         30
# num_trips                                                       416
# route_short_name                                                  3
# route_long_name   Lyall Bay/Rongotai - Kilbirnie - Newtown - Wel...
# route_type                                                        3
#
#                                                         26  \
# route_id                                                20
# num_trips                                              399
# route_short_name                                         2
# route_long_name   Karori - Wellington - Hataitai - Seatoun
# route_type                                               3
#
#                                                 81  \
# route_id                                        70
# num_trips                                      308
# route_short_name                                 7
# route_long_name   Kingston - Brooklyn - Wellington
# route_type                                       3
#
#                                                           8   \
# route_id                                                1200
# num_trips                                                268
# route_short_name                                         120
# route_long_name   Stokes Valley - Taita - Epuni - Lower Hutt
# route_type                                                 3
#
#                                                                1   \
# route_id                                                     1100
# num_trips                                                     265
# route_short_name                                              110
# route_long_name   Emerald Hill - Upper Hutt - Lower Hutt - Petone
# route_type                                                      3
#
#                                        21  \
# route_id                              180
# num_trips                             262
# route_short_name                       18
# route_long_name   Miramar - Miramar Shops
# route_type                              3
#
#                                                        12  \
# route_id                                             1300
# num_trips                                             249
# route_short_name                                      130
# route_long_name   Naenae - Waterloo - Lower Hutt - Petone
# route_type                                              3
#
#                                                  37  \
# route_id                                       2200
# num_trips                                       243
# route_short_name                                220
# route_long_name   Titahi Bay - Porirua - Ascot Park
# route_type                                        3
#
#                                      ...                       \
# route_id                             ...
# num_trips                            ...
# route_short_name                     ...
# route_long_name                      ...
# route_type                           ...
#
#                                       53  \
# route_id                             270
# num_trips                              4
# route_short_name                      27
# route_long_name   Vogeltown - Wellington
# route_type                             3
#
#                                                                  94  \
# route_id                                                       9918
# num_trips                                                         4
# route_short_name                                                 N8
# route_long_name   After Midnight (Lower Hutt - Petone - Wellington)
# route_type                                                        3
#
#                                                        31  \
# route_id                                             2030
# num_trips                                               3
# route_short_name                                      203
# route_long_name   Masterton - Masterton North - Masterton
# route_type                                              3
#
#                                                       29  \
# route_id                                            2010
# num_trips                                              3
# route_short_name                                     201
# route_long_name   Masterton - Masterton West - Masterton
# route_type                                             3
#
#                                                        30  \
# route_id                                             2020
# num_trips                                               3
# route_short_name                                      202
# route_long_name   Masterton - Masterton South - Masterton
# route_type                                              3
#
#                                                       33                60  \
# route_id                                            2060              2910
# num_trips                                              3                 2
# route_short_name                                     206               291
# route_long_name   Masterton - Masterton East - Masterton  Waikanae - Levin
# route_type                                             3                 3
#
#                                                                  52  \
# route_id                                                       2640
# num_trips                                                         2
# route_short_name                                                264
# route_long_name   Paraparaumu East - Paraparaumu - Kapiti Health...
# route_type                                                        3
#
#                                                                 47  \
# route_id                                                      2510
# num_trips                                                        2
# route_short_name                                               251
# route_long_name   Paekakariki - Paraparaumu - Kapiti Health Centre
# route_type                                                       3
#
#                                                            64
# route_id                                                 3000
# num_trips                                                   2
# route_short_name                                          300
# route_long_name   Whenua Tapu Cemetery - Porirua - Titahi Bay
# route_type                                                  3
#
# [5 rows x 98 columns]

# %% [markdown]
# ## Let's put GTFSTK to work

# %%
# Fill in shape_dist_traveled column of stop_times for later distance calculations.
trip_stats = feed.compute_trip_stats()

feed = feed.append_dist_to_stop_times(trip_stats)
feed.stop_times.T
# Out:
#                                          0                           1       \
# trip_id              110__0__101__TZM__521__521  110__0__101__TZM__521__521
# arrival_time                           23:07:00                    23:07:28
# departure_time                         23:07:00                    23:07:28
# stop_id                                    9000                        9002
# stop_sequence                                 0                           1
# stop_headsign                      Emerald Hill                         NaN
# pickup_type                                   0                           0
# drop_off_type                                 1                           0
# shape_dist_traveled                           0                    0.202915
# timepoint                                   NaN                         NaN
#
#                                          2                           3       \
# trip_id              110__0__101__TZM__521__521  110__0__101__TZM__521__521
# arrival_time                           23:08:16                    23:08:39
# departure_time                         23:08:16                    23:08:39
# stop_id                                    9003                        9004
# stop_sequence                                 2                           3
# stop_headsign                               NaN                         NaN
# pickup_type                                   0                           0
# drop_off_type                                 0                           0
# shape_dist_traveled                    0.541467                    0.711481
# timepoint                                   NaN                         NaN
#
#                                          4                           5       \
# trip_id              110__0__101__TZM__521__521  110__0__101__TZM__521__521
# arrival_time                           23:09:31                    23:10:56
# departure_time                         23:09:31                    23:10:56
# stop_id                                    9005                        9007
# stop_sequence                                 4                           5
# stop_headsign                               NaN                         NaN
# pickup_type                                   0                           0
# drop_off_type                                 0                           0
# shape_dist_traveled                     1.06714                       1.638
# timepoint                                   NaN                         NaN
#
#                                          6                           7       \
# trip_id              110__0__101__TZM__521__521  110__0__101__TZM__521__521
# arrival_time                           23:11:36                    23:12:45
# departure_time                         23:11:36                    23:12:45
# stop_id                                    9008                        9009
# stop_sequence                                 6                           7
# stop_headsign                               NaN                         NaN
# pickup_type                                   0                           0
# drop_off_type                                 0                           0
# shape_dist_traveled                     1.91583                     2.38393
# timepoint                                   NaN                         NaN
#
#                                          8                           9       \
# trip_id              110__0__101__TZM__521__521  110__0__101__TZM__521__521
# arrival_time                           23:14:01                    23:14:38
# departure_time                         23:14:01                    23:14:38
# stop_id                                    9110                        9111
# stop_sequence                                 8                           9
# stop_headsign                               NaN                         NaN
# pickup_type                                   0                           0
# drop_off_type                                 0                           0
# shape_dist_traveled                     2.89787                      3.1613
# timepoint                                   NaN                         NaN
#
#                                    ...                 \
# trip_id                            ...
# arrival_time                       ...
# departure_time                     ...
# stop_id                            ...
# stop_sequence                      ...
# stop_headsign                      ...
# pickup_type                        ...
# drop_off_type                      ...
# shape_dist_traveled                ...
# timepoint                          ...
#
#                                                299467  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 06:27:00
# departure_time                               06:27:00
# stop_id                                          SOLW
# stop_sequence                                       2
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           2.85028
# timepoint                                         NaN
#
#                                                299468  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 06:38:00
# departure_time                               06:38:00
# stop_id                                          CART
# stop_sequence                                       3
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                            14.349
# timepoint                                         NaN
#
#                                                299469  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 06:48:00
# departure_time                               06:48:00
# stop_id                                          MATA
# stop_sequence                                       4
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           21.3971
# timepoint                                         NaN
#
#                                                299470  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 06:53:00
# departure_time                               06:53:00
# stop_id                                          WOOD
# stop_sequence                                       5
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           25.8837
# timepoint                                         NaN
#
#                                                299471  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 07:02:00
# departure_time                               07:02:00
# stop_id                                          FEAT
# stop_sequence                                       6
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           33.8883
# timepoint                                         NaN
#
#                                                299472  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 07:23:00
# departure_time                               07:23:00
# stop_id                                          MAYM
# stop_sequence                                       7
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           52.2671
# timepoint                                         NaN
#
#                                                299473  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 07:32:00
# departure_time                               07:32:00
# stop_id                                          UPPE
# stop_sequence                                       8
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           58.5921
# timepoint                                         NaN
#
#                                                299474  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 07:50:00
# departure_time                               07:50:00
# stop_id                                         WATE1
# stop_sequence                                       9
# stop_headsign                                     NaN
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           75.5015
# timepoint                                         NaN
#
#                                                299475  \
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 07:58:00
# departure_time                               07:58:00
# stop_id                                         PETO1
# stop_sequence                                      10
# stop_headsign                         WELL - Non stop
# pickup_type                                         0
# drop_off_type                                       0
# shape_dist_traveled                           80.4869
# timepoint                                         NaN
#
#                                                299476
# trip_id              WRL__1__1693__RAIL__Special_Xmas
# arrival_time                                 08:10:00
# departure_time                               08:10:00
# stop_id                                          WELL
# stop_sequence                                      11
# stop_headsign                                     NaN
# pickup_type                                         1
# drop_off_type                                       0
# shape_dist_traveled                           90.9659
# timepoint                                         NaN
#
# [10 rows x 299477 columns]

# %%
# Trip stats
trip_stats.T
# Out:
#                                             2518                      2519  \
# trip_id           1__0__101__TZM__101__2__101__2  1__0__103__TZM__104__104
# route_id                                      10                        10
# route_short_name                               1                         1
# route_type                                     3                         3
# direction_id                                   0                         0
# shape_id                     [@356.0.16077561@]7      [@356.0.16077561@]12
# num_stops                                     53                        63
# start_time                              05:40:00                  06:00:00
# end_time                                06:40:00                  06:59:00
# start_stop_id                               7158                      7158
# end_stop_id                                 3279                      3451
# is_loop                                        0                         0
# duration                                       1                  0.983333
# distance                                 21.7313                    23.353
# speed                                    21.7313                   23.7488
#
#                                             2520  \
# trip_id           1__0__105__TZM__109__1__109__1
# route_id                                      10
# route_short_name                               1
# route_type                                     3
# direction_id                                   0
# shape_id                     [@356.0.16077561@]7
# num_stops                                     53
# start_time                              06:20:00
# end_time                                07:20:00
# start_stop_id                               7158
# end_stop_id                                 3279
# is_loop                                        0
# duration                                       1
# distance                                 21.7313
# speed                                    21.7313
#
#                                             2614                      2521  \
# trip_id           1__0__401__TZM__101__3__101__3  1__0__107__TZM__115__115
# route_id                                      10                        10
# route_short_name                               1                         1
# route_type                                     3                         3
# direction_id                                   0                         0
# shape_id                     [@356.0.16077561@]7      [@356.0.16077561@]12
# num_stops                                     53                        63
# start_time                              06:35:00                  06:40:00
# end_time                                07:39:00                  07:39:00
# start_stop_id                               7158                      7158
# end_stop_id                                 3279                      3451
# is_loop                                        0                         0
# duration                                 1.06667                  0.983333
# distance                                 21.7313                    23.353
# speed                                    20.3731                   23.7488
#
#                                       2522                      2523  \
# trip_id           1__0__109__TZM__123__123  1__0__111__TZM__124__124
# route_id                                10                        10
# route_short_name                         1                         1
# route_type                               3                         3
# direction_id                             0                         0
# shape_id               [@356.0.16077561@]7      [@356.0.16077561@]12
# num_stops                               53                        63
# start_time                        06:55:00                  07:05:00
# end_time                          08:00:00                  08:10:00
# start_stop_id                         7158                      7158
# end_stop_id                           3279                      3451
# is_loop                                  0                         0
# duration                           1.08333                   1.08333
# distance                           21.7313                    23.353
# speed                              20.0597                   21.5566
#
#                                             2615  \
# trip_id           1__0__403__TZM__106__1__106__1
# route_id                                      10
# route_short_name                               1
# route_type                                     3
# direction_id                                   0
# shape_id                     [@356.0.16077561@]7
# num_stops                                     53
# start_time                              07:05:00
# end_time                                08:09:00
# start_stop_id                               7158
# end_stop_id                                 3279
# is_loop                                        0
# duration                                 1.06667
# distance                                 21.7313
# speed                                    20.3731
#
#                                             2675  \
# trip_id           1__0__701__TZM__101__4__101__4
# route_id                                      10
# route_short_name                               1
# route_type                                     3
# direction_id                                   0
# shape_id                     [@356.0.16077561@]7
# num_stops                                     53
# start_time                              07:05:00
# end_time                                08:09:00
# start_stop_id                               7158
# end_stop_id                                 3279
# is_loop                                        0
# duration                                 1.06667
# distance                                 21.7313
# speed                                    20.3731
#
#                                             2524  \
# trip_id           1__0__113__TZM__203__1__203__1
# route_id                                      10
# route_short_name                               1
# route_type                                     3
# direction_id                                   0
# shape_id                    [@356.0.16077561@]10
# num_stops                                     58
# start_time                              07:15:00
# end_time                                08:20:00
# start_stop_id                               7158
# end_stop_id                                 3040
# is_loop                                        0
# duration                                 1.08333
# distance                                 21.8925
# speed                                    20.2085
#
#                                 ...                 \
# trip_id                         ...
# route_id                        ...
# route_short_name                ...
# route_type                      ...
# direction_id                    ...
# shape_id                        ...
# num_stops                       ...
# start_time                      ...
# end_time                        ...
# start_stop_id                   ...
# end_stop_id                     ...
# is_loop                         ...
# duration                        ...
# distance                        ...
# speed                           ...
#
#                                               8531  \
# trip_id           N66__0__101__TZM__605__1__605__1
# route_id                                      9966
# route_short_name                               N66
# route_type                                       3
# direction_id                                     0
# shape_id            [@6.0.22109575@]N66:18#729#814
# num_stops                                       83
# start_time                                01:30:00
# end_time                                  02:30:00
# start_stop_id                                 5000
# end_stop_id                                   8921
# is_loop                                          0
# duration                                         1
# distance                                   39.5107
# speed                                      39.5107
#
#                                               8532  \
# trip_id           N66__0__101__TZM__605__4__605__4
# route_id                                      9966
# route_short_name                               N66
# route_type                                       3
# direction_id                                     0
# shape_id            [@6.0.22109575@]N66:18#729#814
# num_stops                                       83
# start_time                                01:30:00
# end_time                                  02:30:00
# start_stop_id                                 5000
# end_stop_id                                   8921
# is_loop                                          0
# duration                                         1
# distance                                   39.5107
# speed                                      39.5107
#
#                                               8533  \
# trip_id           N66__0__103__TZM__605__1__605__1
# route_id                                      9966
# route_short_name                               N66
# route_type                                       3
# direction_id                                     0
# shape_id            [@6.0.22109575@]N66:18#729#814
# num_stops                                       83
# start_time                                03:00:00
# end_time                                  04:00:00
# start_stop_id                                 5000
# end_stop_id                                   8921
# is_loop                                          0
# duration                                         1
# distance                                   39.5107
# speed                                      39.5107
#
#                                               8534  \
# trip_id           N66__0__103__TZM__605__4__605__4
# route_id                                      9966
# route_short_name                               N66
# route_type                                       3
# direction_id                                     0
# shape_id            [@6.0.22109575@]N66:18#729#814
# num_stops                                       83
# start_time                                03:00:00
# end_time                                  04:00:00
# start_stop_id                                 5000
# end_stop_id                                   8921
# is_loop                                          0
# duration                                         1
# distance                                   39.5107
# speed                                      39.5107
#
#                                               8545  \
# trip_id               N88__0__101__NBM__1__1__1__1
# route_id                                      9988
# route_short_name                               N88
# route_type                                       3
# direction_id                                     0
# shape_id          [@356.0.30313526@]N88:20#819#882
# num_stops                                       66
# start_time                                00:30:00
# end_time                                  01:30:00
# start_stop_id                                 5000
# end_stop_id                                   9858
# is_loop                                          0
# duration                                         1
# distance                                   32.2557
# speed                                      32.2557
#
#                                               8546  \
# trip_id               N88__0__101__NBM__1__2__1__2
# route_id                                      9988
# route_short_name                               N88
# route_type                                       3
# direction_id                                     0
# shape_id          [@356.0.30313526@]N88:20#819#882
# num_stops                                       66
# start_time                                00:30:00
# end_time                                  01:30:00
# start_stop_id                                 5000
# end_stop_id                                   9858
# is_loop                                          0
# duration                                         1
# distance                                   32.2557
# speed                                      32.2557
#
#                                               8547  \
# trip_id               N88__0__103__NBM__2__1__2__1
# route_id                                      9988
# route_short_name                               N88
# route_type                                       3
# direction_id                                     0
# shape_id          [@356.0.30313526@]N88:20#819#882
# num_stops                                       66
# start_time                                02:00:00
# end_time                                  03:00:00
# start_stop_id                                 5000
# end_stop_id                                   9858
# is_loop                                          0
# duration                                         1
# distance                                   32.2557
# speed                                      32.2557
#
#                                               8548  \
# trip_id               N88__0__103__NBM__2__2__2__2
# route_id                                      9988
# route_short_name                               N88
# route_type                                       3
# direction_id                                     0
# shape_id          [@356.0.30313526@]N88:20#819#882
# num_stops                                       66
# start_time                                02:00:00
# end_time                                  03:00:00
# start_stop_id                                 5000
# end_stop_id                                   9858
# is_loop                                          0
# duration                                         1
# distance                                   32.2557
# speed                                      32.2557
#
#                                               8549  \
# trip_id               N88__0__105__NBM__2__1__2__1
# route_id                                      9988
# route_short_name                               N88
# route_type                                       3
# direction_id                                     0
# shape_id          [@356.0.30313526@]N88:20#819#882
# num_stops                                       66
# start_time                                03:30:00
# end_time                                  04:30:00
# start_stop_id                                 5000
# end_stop_id                                   9858
# is_loop                                          0
# duration                                         1
# distance                                   32.2557
# speed                                      32.2557
#
#                                               8550
# trip_id               N88__0__105__NBM__2__2__2__2
# route_id                                      9988
# route_short_name                               N88
# route_type                                       3
# direction_id                                     0
# shape_id          [@356.0.30313526@]N88:20#819#882
# num_stops                                       66
# start_time                                03:30:00
# end_time                                  04:30:00
# start_stop_id                                 5000
# end_stop_id                                   9858
# is_loop                                          0
# duration                                         1
# distance                                   32.2557
# speed                                      32.2557
#
# [15 rows x 8621 columns]

# %%
# Route stats
route_stats = feed.compute_route_stats(trip_stats, dates=[DATE])
route_stats.T
# Out:
#                           0         1         2         3         4   \
# route_id                  10      1100      1110      1120      1130
# route_short_name           1       110       111       112       113
# route_type                 3         3         3         3         3
# num_trips                192       107        29        39         8
# num_trip_starts          192       107        29        39         8
# num_trip_ends            188       107        29        39         8
# is_loop                    0         0         1         0         0
# is_bidirectional           1         1         0         1         1
# start_time          05:40:00  05:38:00  06:22:00  06:10:00  06:55:00
# end_time            24:45:00  23:09:00  19:02:00  19:13:00  18:28:00
# max_headway               19        35        49        60       123
# min_headway                2         0        16        10        40
# mean_headway         9.51678      15.3     27.76   41.7273      89.6
# peak_num_trips            22        13         1         2         1
# peak_start_time     17:17:00  15:42:00  06:34:00  06:53:00  07:32:00
# peak_end_time       17:20:00  15:46:00  06:51:00  07:10:00  07:50:00
# service_distance     4226.21   3235.05     184.8   385.109   65.4401
# service_duration     219.017     116.4   6.48333   13.2167       2.3
# service_speed        19.2963   27.7926   28.5039   29.1381   28.4522
# mean_trip_distance   22.0115   30.2342   6.37243   9.87459   8.18002
# mean_trip_duration   1.14071   1.08785  0.223563  0.338889    0.2875
# date                20190408  20190408  20190408  20190408  20190408
#
#                           5         6         7         8         9   \
# route_id                1140      1150       120      1200       121
# route_short_name         114       115        12       120       12e
# route_type                 3         3         3         3         3
# num_trips                 31        18        66       112        11
# num_trip_starts           31        18        66       112        11
# num_trip_ends             31        18        65       112        11
# is_loop                    0         1         0         0         0
# is_bidirectional           1         0         1         1         1
# start_time          06:20:00  06:30:00  05:52:00  05:55:00  06:40:00
# end_time            18:50:00  18:28:00  24:00:00  22:51:00  19:02:00
# max_headway               60        60        62        30        34
# min_headway               21        18        15         2        30
# mean_headway         49.4815   43.6667   28.4255   14.8632      30.5
# peak_num_trips             2         2         2         7         2
# peak_start_time     08:01:00  17:00:00  17:30:00  08:28:00  08:40:00
# peak_end_time       08:18:00  17:32:00  17:47:00  08:32:00  08:58:00
# service_distance     248.822   404.722   451.802   1593.21   140.433
# service_duration     9.03333      13.5     17.55   56.2833   8.36667
# service_speed        27.5449   29.9794   25.7437   28.3069   16.7848
# mean_trip_distance   8.02652   22.4846   6.84549   14.2251   12.7666
# mean_trip_duration  0.291398      0.75  0.265909   0.50253  0.760606
# date                20190408  20190408  20190408  20190408  20190408
#
#                       ...            75        76        77        78  \
# route_id              ...             6       600       601        70
# route_short_name      ...           JVL        60       60e         7
# route_type            ...             2         3         3         3
# num_trips             ...            90        68        11       139
# num_trip_starts       ...            90        68        11       139
# num_trip_ends         ...            90        68        11       138
# is_loop               ...             0         0         0         0
# is_bidirectional      ...             1         1         1         1
# start_time            ...      05:32:00  06:40:00  06:25:00  06:00:00
# end_time              ...      23:53:00  21:54:00  18:51:00  24:23:00
# max_headway           ...            35        60       496        16
# min_headway           ...            15         7        19         8
# mean_headway          ...       21.5385   21.1167   94.5714        13
# peak_num_trips        ...             4         4         5         7
# peak_start_time       ...      06:45:00  15:32:00  07:52:00  08:10:00
# peak_end_time         ...      06:53:00  15:40:00  08:25:00  08:17:00
# service_distance      ...       928.834   884.386   272.297    943.35
# service_duration      ...       36.3333      29.3   11.4667   64.1333
# service_speed         ...       25.5642   30.1838   23.7468   14.7092
# mean_trip_distance    ...       10.3204   13.0057   24.7543   6.78669
# mean_trip_duration    ...      0.403704  0.430882   1.04242  0.461391
# date                  ...      20190408  20190408  20190408  20190408
#
#                           79        80        81        82        83  \
# route_id                   8       810       830       840       850
# route_short_name         WHF        81        83        84       85x
# route_type                 4         3         3         3         3
# num_trips                 32        29        58        13         5
# num_trip_starts           32        29        58        13         5
# num_trip_ends             32        29        57        13         5
# is_loop                    0         0         0         0         0
# is_bidirectional           1         1         1         1         1
# start_time          06:20:00  05:55:00  06:05:00  06:45:00  06:55:00
# end_time            19:55:00  19:30:00  24:24:00  18:30:00  18:14:00
# max_headway              150       450        60        30       105
# min_headway               15        10        20         5        40
# mean_headway              55   52.0833   30.6667      19.1      72.5
# peak_num_trips             2         6         6         4         2
# peak_start_time     08:20:00  18:00:00  17:05:00  16:25:00  07:15:00
# peak_end_time       09:10:00  18:09:00  17:19:00  16:32:00  07:49:00
# service_distance     382.077   804.392   1863.72   299.146   135.758
# service_duration     16.0833   27.9333   66.0667   9.78333   5.08333
# service_speed        23.7561   28.7968   28.2097   30.5771   26.7064
# mean_trip_distance   11.9399   27.7377   32.1331   23.0112   27.1515
# mean_trip_duration  0.502604  0.963218   1.13908  0.752564   1.01667
# date                20190408  20190408  20190408  20190408  20190408
#
#                            84
# route_id                    9
# route_short_name          CCL
# route_type                  5
# num_trips                 182
# num_trip_starts           182
# num_trip_ends             182
# is_loop                     0
# is_bidirectional            1
# start_time           07:00:00
# end_time             22:05:00
# max_headway                10
# min_headway                10
# mean_headway               10
# peak_num_trips              2
# peak_start_time      07:00:00
# peak_end_time        07:05:00
# service_distance      115.832
# service_duration      15.1667
# service_speed          7.6373
# mean_trip_distance   0.636442
# mean_trip_duration  0.0833333
# date                 20190408
#
# [22 rows x 85 columns]

# %%
# Join in route long name
route_stats = route_stats.merge(feed.routes.filter(["route_id", "route_long_name"]))

cols = [
    "route_id",
    "route_short_name", 
    "route_long_name", 
    "route_type", 
    "start_time",
    "end_time",
    "num_trips",
    "max_headway",
    "mean_trip_distance",
    "mean_trip_duration",
    "service_speed",
]

# %%
# The most/least frequent routes are
(
    route_stats
    .filter(cols)
    .sort_values("max_headway")
    .T
)
# Out:
#                                                   84  \
# route_id                                           9
# route_short_name                                 CCL
# route_long_name     Cable Car (Kelburn - Wellington)
# route_type                                         5
# start_time                                  07:00:00
# end_time                                    22:05:00
# num_trips                                        182
# max_headway                                       10
# mean_trip_distance                          0.636442
# mean_trip_duration                         0.0833333
# service_speed                                 7.6373
#
#                                                           26  \
# route_id                                                  20
# route_short_name                                           2
# route_long_name     Karori - Wellington - Hataitai - Seatoun
# route_type                                                 3
# start_time                                          06:00:00
# end_time                                            24:22:00
# num_trips                                                182
# max_headway                                               15
# mean_trip_distance                                   18.1043
# mean_trip_duration                                  0.959524
# service_speed                                        18.8681
#
#                                                   78  \
# route_id                                          70
# route_short_name                                   7
# route_long_name     Kingston - Brooklyn - Wellington
# route_type                                         3
# start_time                                  06:00:00
# end_time                                    24:23:00
# num_trips                                        139
# max_headway                                       16
# mean_trip_distance                           6.78669
# mean_trip_duration                          0.461391
# service_speed                                14.7092
#
#                                                                    60  \
# route_id                                                           30
# route_short_name                                                    3
# route_long_name     Lyall Bay/Rongotai - Kilbirnie - Newtown - Wel...
# route_type                                                          3
# start_time                                                   06:00:00
# end_time                                                     24:23:00
# num_trips                                                         180
# max_headway                                                        17
# mean_trip_distance                                            9.18586
# mean_trip_duration                                           0.645185
# service_speed                                                 14.2376
#
#                                        74                      73  \
# route_id                              580                     570
# route_short_name                       58                      57
# route_long_name     Newlands - Wellington  Woodridge - Wellington
# route_type                              3                       3
# start_time                       06:34:00                06:32:00
# end_time                         18:32:00                18:26:00
# num_trips                              14                      14
# max_headway                            19                      19
# mean_trip_distance                  14.02                 13.3994
# mean_trip_duration               0.778571                0.728571
# service_speed                     18.0073                 18.3913
#
#                                                        72  \
# route_id                                              560
# route_short_name                                       56
# route_long_name     Johnsonville - Paparangi - Wellington
# route_type                                              3
# start_time                                       06:22:00
# end_time                                         18:22:00
# num_trips                                              13
# max_headway                                            19
# mean_trip_distance                                14.7166
# mean_trip_duration                               0.787179
# service_speed                                     18.6954
#
#                                                                    0   \
# route_id                                                           10
# route_short_name                                                    1
# route_long_name     Johnsonville West/Churton Park/Grenada Village...
# route_type                                                          3
# start_time                                                   05:40:00
# end_time                                                     24:45:00
# num_trips                                                         192
# max_headway                                                        19
# mean_trip_distance                                            22.0115
# mean_trip_duration                                            1.14071
# service_speed                                                 19.2963
#
#                                                                67  \
# route_id                                                      360
# route_short_name                                               36
# route_long_name     Lyall Bay - Kilbirnie - Hataitai - Wellington
# route_type                                                      3
# start_time                                               05:47:00
# end_time                                                 18:36:00
# num_trips                                                      24
# max_headway                                                    20
# mean_trip_distance                                        7.21254
# mean_trip_duration                                       0.558333
# service_speed                                              12.918
#
#                                        66  \
# route_id                              350
# route_short_name                       35
# route_long_name     Hataitai - Wellington
# route_type                              3
# start_time                       07:20:00
# end_time                         18:22:00
# num_trips                              10
# max_headway                            20
# mean_trip_distance                6.13191
# mean_trip_duration               0.506667
# service_speed                     12.1024
#
#                                           ...                          \
# route_id                                  ...
# route_short_name                          ...
# route_long_name                           ...
# route_type                                ...
# start_time                                ...
# end_time                                  ...
# num_trips                                 ...
# max_headway                               ...
# mean_trip_distance                        ...
# mean_trip_duration                        ...
# service_speed                             ...
#
#                                                          31  \
# route_id                                               2030
# route_short_name                                        203
# route_long_name     Masterton - Masterton North - Masterton
# route_type                                                3
# start_time                                         09:55:00
# end_time                                           14:50:00
# num_trips                                                 3
# max_headway                                             190
# mean_trip_distance                                  11.7909
# mean_trip_duration                                      0.5
# service_speed                                       23.5818
#
#                                                          69  \
# route_id                                                  4
# route_short_name                                        WRL
# route_long_name     Wairarapa Line (Masterton - Wellington)
# route_type                                                2
# start_time                                         05:46:00
# end_time                                           20:03:00
# num_trips                                                10
# max_headway                                             308
# mean_trip_distance                                  90.9667
# mean_trip_duration                                  1.72667
# service_speed                                       52.6834
#
#                                      32                                    62  \
# route_id                           2040                                   310
# route_short_name                    204                                   31x
# route_long_name     Greytown - Woodside  Miramar North - Wellington (Express)
# route_type                            3                                     3
# start_time                     05:56:00                              06:26:00
# end_time                       19:55:00                              19:12:00
# num_trips                            10                                    23
# max_headway                         308                                   424
# mean_trip_distance              11.3971                               10.6905
# mean_trip_duration                 0.26                               0.59058
# service_speed                   43.8349                               18.1016
#
#                                                      47  \
# route_id                                            260
# route_short_name                                     26
# route_long_name     Khandallah - Ngaio - Brandon Street
# route_type                                            3
# start_time                                     06:37:00
# end_time                                       18:55:00
# num_trips                                            31
# max_headway                                         435
# mean_trip_distance                              9.00953
# mean_trip_duration                              0.41129
# service_speed                                   21.9055
#
#                                                                    24  \
# route_id                                                          191
# route_short_name                                                  19e
# route_long_name     Johnsonville - Churton Park - Johnsonville (We...
# route_type                                                          3
# start_time                                                   05:50:00
# end_time                                                     19:18:00
# num_trips                                                          16
# max_headway                                                       438
# mean_trip_distance                                            18.4278
# mean_trip_duration                                           0.801042
# service_speed                                                 23.0048
#
#                                                   80  \
# route_id                                         810
# route_short_name                                  81
# route_long_name     Eastbourne - Petone - Wellington
# route_type                                         3
# start_time                                  05:55:00
# end_time                                    19:30:00
# num_trips                                         29
# max_headway                                      450
# mean_trip_distance                           27.7377
# mean_trip_duration                          0.963218
# service_speed                                28.7968
#
#                                                                    58  \
# route_id                                                          291
# route_short_name                                                  29e
# route_long_name     Newtown - Southgate - Owhiro Bay - Brooklyn (W...
# route_type                                                          3
# start_time                                                   06:45:00
# end_time                                                     18:38:00
# num_trips                                                          16
# max_headway                                                       487
# mean_trip_distance                                            13.7094
# mean_trip_duration                                           0.810417
# service_speed                                                 16.9165
#
#                                                             77  \
# route_id                                                   601
# route_short_name                                           60e
# route_long_name     Porirua - Tawa - Johnsonville - Wellington
# route_type                                                   3
# start_time                                            06:25:00
# end_time                                              18:51:00
# num_trips                                                   11
# max_headway                                                496
# mean_trip_distance                                     24.7543
# mean_trip_duration                                     1.04242
# service_speed                                          23.7468
#
#                                                                    51
# route_id                                                         2640
# route_short_name                                                  264
# route_long_name     Paraparaumu East - Paraparaumu - Kapiti Health...
# route_type                                                          3
# start_time                                                   10:25:00
# end_time                                                     13:50:00
# num_trips                                                           2
# max_headway                                                       NaN
# mean_trip_distance                                            4.77594
# mean_trip_duration                                           0.333333
# service_speed                                                 14.3278
#
# [11 rows x 85 columns]

# %%
# The shortest/longest routes are
(
    route_stats
    .filter(cols)
    .sort_values("mean_trip_distance")
    .T
)
# Out:
#                                                   84                       21  \
# route_id                                           9                      180
# route_short_name                                 CCL                       18
# route_long_name     Cable Car (Kelburn - Wellington)  Miramar - Miramar Shops
# route_type                                         5                        3
# start_time                                  07:00:00                 06:13:00
# end_time                                    22:05:00                 23:22:00
# num_trips                                        182                      104
# max_headway                                       10                      127
# mean_trip_distance                          0.636442                  2.03534
# mean_trip_duration                         0.0833333                0.0894231
# service_speed                                 7.6373                  22.7608
#
#                                         18  \
# route_id                               170
# route_short_name                        17
# route_long_name     Kowhai Park - Brooklyn
# route_type                               3
# start_time                        06:20:00
# end_time                          23:58:00
# num_trips                               60
# max_headway                             35
# mean_trip_distance                 3.16134
# mean_trip_duration                0.151389
# service_speed                      20.8822
#
#                                                      53  \
# route_id                                            280
# route_short_name                                     28
# route_long_name     Beacon Hill - Strathmore Park Shops
# route_type                                            3
# start_time                                     06:57:00
# end_time                                       18:40:00
# num_trips                                            15
# max_headway                                          30
# mean_trip_distance                              3.69959
# mean_trip_duration                             0.166667
# service_speed                                   22.1976
#
#                                                                    51  \
# route_id                                                         2640
# route_short_name                                                  264
# route_long_name     Paraparaumu East - Paraparaumu - Kapiti Health...
# route_type                                                          3
# start_time                                                   10:25:00
# end_time                                                     13:50:00
# num_trips                                                           2
# max_headway                                                       NaN
# mean_trip_distance                                            4.77594
# mean_trip_duration                                           0.333333
# service_speed                                                 14.3278
#
#                                                         33  \
# route_id                                              2060
# route_short_name                                       206
# route_long_name     Masterton - Masterton East - Masterton
# route_type                                               3
# start_time                                        10:25:00
# end_time                                          15:15:00
# num_trips                                                3
# max_headway                                            170
# mean_trip_distance                                 4.90849
# mean_trip_duration                                    0.25
# service_speed                                       19.634
#
#                                                                    34  \
# route_id                                                          210
# route_short_name                                                   21
# route_long_name     Karori (Wrights Hill) - Kelburn - Courtenay Place
# route_type                                                          3
# start_time                                                   06:25:00
# end_time                                                     23:54:00
# num_trips                                                         127
# max_headway                                                        30
# mean_trip_distance                                            5.55176
# mean_trip_duration                                           0.283465
# service_speed                                                 19.5854
#
#                                              42                     66  \
# route_id                                    232                    350
# route_short_name                            23z                     35
# route_long_name     Wellington Zoo - Wellington  Hataitai - Wellington
# route_type                                    3                      3
# start_time                             09:05:00               07:20:00
# end_time                               18:13:00               18:22:00
# num_trips                                    14                     10
# max_headway                                  60                     20
# mean_trip_distance                       5.8886                6.13191
# mean_trip_duration                     0.519048               0.506667
# service_speed                            11.345                12.1024
#
#                                                        2   \
# route_id                                             1110
# route_short_name                                      111
# route_long_name     Upper Hutt - Totara Park - Upper Hutt
# route_type                                              3
# start_time                                       06:22:00
# end_time                                         19:02:00
# num_trips                                              29
# max_headway                                            49
# mean_trip_distance                                6.37243
# mean_trip_duration                               0.223563
# service_speed                                     28.5039
#
#                                      ...                     \
# route_id                             ...
# route_short_name                     ...
# route_long_name                      ...
# route_type                           ...
# start_time                           ...
# end_time                             ...
# num_trips                            ...
# max_headway                          ...
# mean_trip_distance                   ...
# mean_trip_duration                   ...
# service_speed                        ...
#
#                                                    83  \
# route_id                                          850
# route_short_name                                  85x
# route_long_name     Eastbourne - Wellington (Express)
# route_type                                          3
# start_time                                   06:55:00
# end_time                                     18:14:00
# num_trips                                           5
# max_headway                                       105
# mean_trip_distance                            27.1515
# mean_trip_duration                            1.01667
# service_speed                                 26.7064
#
#                                                   80  \
# route_id                                         810
# route_short_name                                  81
# route_long_name     Eastbourne - Petone - Wellington
# route_type                                         3
# start_time                                  05:55:00
# end_time                                    19:30:00
# num_trips                                         29
# max_headway                                      450
# mean_trip_distance                           27.7377
# mean_trip_duration                          0.963218
# service_speed                                28.7968
#
#                                                                    10  \
# route_id                                                         1210
# route_short_name                                                  121
# route_long_name     Stokes Valley Heights - Naenae - Lower Hutt - ...
# route_type                                                          3
# start_time                                                   05:45:00
# end_time                                                     19:37:00
# num_trips                                                          35
# max_headway                                                        70
# mean_trip_distance                                            29.2399
# mean_trip_duration                                           0.934762
# service_speed                                                 31.2806
#
#                                                                  1   \
# route_id                                                       1100
# route_short_name                                                110
# route_long_name     Emerald Hill - Upper Hutt - Lower Hutt - Petone
# route_type                                                        3
# start_time                                                 05:38:00
# end_time                                                   23:09:00
# num_trips                                                       107
# max_headway                                                      35
# mean_trip_distance                                          30.2342
# mean_trip_duration                                          1.08785
# service_speed                                               27.7926
#
#                                                             70  \
# route_id                                                     5
# route_short_name                                           HVL
# route_long_name     Hutt Valley Line (Upper Hutt - Wellington)
# route_type                                                   2
# start_time                                            04:30:00
# end_time                                              23:50:00
# num_trips                                                  111
# max_headway                                                 30
# mean_trip_distance                                     30.4569
# mean_trip_duration                                    0.685736
# service_speed                                           44.415
#
#                                                                81  \
# route_id                                                      830
# route_short_name                                               83
# route_long_name     Eastbourne - Lower Hutt - Petone - Wellington
# route_type                                                      3
# start_time                                               06:05:00
# end_time                                                 24:24:00
# num_trips                                                      58
# max_headway                                                    60
# mean_trip_distance                                        32.1331
# mean_trip_duration                                        1.13908
# service_speed                                             28.2097
#
#                                                                    28  \
# route_id                                                         2000
# route_short_name                                                  200
# route_long_name     Masterton - Greytown - Featherston - Martinbor...
# route_type                                                          3
# start_time                                                   05:55:00
# end_time                                                     19:50:00
# num_trips                                                          20
# max_headway                                                       170
# mean_trip_distance                                            40.5565
# mean_trip_duration                                           0.849167
# service_speed                                                 47.7604
#
#                                                      25  \
# route_id                                              2
# route_short_name                                    KPL
# route_long_name     Kapiti Line (Waikanae - Wellington)
# route_type                                            2
# start_time                                     05:00:00
# end_time                                       24:14:00
# num_trips                                           117
# max_headway                                          30
# mean_trip_distance                               47.879
# mean_trip_duration                             0.865812
# service_speed                                   55.2995
#
#                                              57  \
# route_id                                   2900
# route_short_name                            290
# route_long_name     Waikanae - Otaki - Waikanae
# route_type                                    3
# start_time                             06:26:00
# end_time                               19:18:00
# num_trips                                     9
# max_headway                                 147
# mean_trip_distance                      50.0839
# mean_trip_duration                      1.09074
# service_speed                           45.9173
#
#                                                          69
# route_id                                                  4
# route_short_name                                        WRL
# route_long_name     Wairarapa Line (Masterton - Wellington)
# route_type                                                2
# start_time                                         05:46:00
# end_time                                           20:03:00
# num_trips                                                10
# max_headway                                             308
# mean_trip_distance                                  90.9667
# mean_trip_duration                                  1.72667
# service_speed                                       52.6834
#
# [11 rows x 85 columns]

# %%
# The slowest/fastest routes are
(
    route_stats
    .filter(cols)
    .sort_values("service_speed")
    .T
)
# Out:
#                                                   84  \
# route_id                                           9
# route_short_name                                 CCL
# route_long_name     Cable Car (Kelburn - Wellington)
# route_type                                         5
# start_time                                  07:00:00
# end_time                                    22:05:00
# num_trips                                        182
# max_headway                                       10
# mean_trip_distance                          0.636442
# mean_trip_duration                         0.0833333
# service_speed                                 7.6373
#
#                                              42                     66  \
# route_id                                    232                    350
# route_short_name                            23z                     35
# route_long_name     Wellington Zoo - Wellington  Hataitai - Wellington
# route_type                                    3                      3
# start_time                             09:05:00               07:20:00
# end_time                               18:13:00               18:22:00
# num_trips                                    14                     10
# max_headway                                  60                     20
# mean_trip_distance                       5.8886                6.13191
# mean_trip_duration                     0.519048               0.506667
# service_speed                            11.345                12.1024
#
#                                                      20  \
# route_id                                            171
# route_short_name                                    17e
# route_long_name     Kowhai Park - Brooklyn - Wellington
# route_type                                            3
# start_time                                     07:10:00
# end_time                                       18:44:00
# num_trips                                            11
# max_headway                                          30
# mean_trip_distance                              7.41276
# mean_trip_duration                             0.598485
# service_speed                                   12.3859
#
#                                                      41  \
# route_id                                            231
# route_short_name                                    23e
# route_long_name     Houghton Bay - Newtown - Wellington
# route_type                                            3
# start_time                                     06:40:00
# end_time                                       19:33:00
# num_trips                                            19
# max_headway                                          54
# mean_trip_distance                              9.02705
# mean_trip_duration                             0.720175
# service_speed                                   12.5345
#
#                                                                67  \
# route_id                                                      360
# route_short_name                                               36
# route_long_name     Lyall Bay - Kilbirnie - Hataitai - Wellington
# route_type                                                      3
# start_time                                               05:47:00
# end_time                                                 18:36:00
# num_trips                                                      24
# max_headway                                                    20
# mean_trip_distance                                        7.21254
# mean_trip_duration                                       0.558333
# service_speed                                              12.918
#
#                                         52  \
# route_id                               270
# route_short_name                        27
# route_long_name     Vogeltown - Wellington
# route_type                               3
# start_time                        07:20:00
# end_time                          18:47:00
# num_trips                                4
# max_headway                             60
# mean_trip_distance                 7.00111
# mean_trip_duration                0.541667
# service_speed                      12.9251
#
#                                                                    60  \
# route_id                                                           30
# route_short_name                                                    3
# route_long_name     Lyall Bay/Rongotai - Kilbirnie - Newtown - Wel...
# route_type                                                          3
# start_time                                                   06:00:00
# end_time                                                     24:23:00
# num_trips                                                         180
# max_headway                                                        17
# mean_trip_distance                                            9.18586
# mean_trip_duration                                           0.645185
# service_speed                                                 14.2376
#
#                                                                    51  \
# route_id                                                         2640
# route_short_name                                                  264
# route_long_name     Paraparaumu East - Paraparaumu - Kapiti Health...
# route_type                                                          3
# start_time                                                   10:25:00
# end_time                                                     13:50:00
# num_trips                                                           2
# max_headway                                                       NaN
# mean_trip_distance                                            4.77594
# mean_trip_duration                                           0.333333
# service_speed                                                 14.3278
#
#                                                                    63  \
# route_id                                                          320
# route_short_name                                                  32x
# route_long_name     Houghton Bay - Island Bay - Berhampore - Welli...
# route_type                                                          3
# start_time                                                   06:40:00
# end_time                                                     19:09:00
# num_trips                                                          24
# max_headway                                                        30
# mean_trip_distance                                            10.1157
# mean_trip_duration                                           0.702083
# service_speed                                                 14.4082
#
#                                    ...                   \
# route_id                           ...
# route_short_name                   ...
# route_long_name                    ...
# route_type                         ...
# start_time                         ...
# end_time                           ...
# num_trips                          ...
# max_headway                        ...
# mean_trip_distance                 ...
# mean_trip_duration                 ...
# service_speed                      ...
#
#                                                                    50  \
# route_id                                                         2620
# route_short_name                                                  262
# route_long_name     Paraparaumu Beach - Paraparaumu (via Mazengarb...
# route_type                                                          3
# start_time                                                   06:08:00
# end_time                                                     21:34:00
# num_trips                                                          52
# max_headway                                                        60
# mean_trip_distance                                            9.45167
# mean_trip_duration                                                0.3
# service_speed                                                 31.5056
#
#                                                            17  \
# route_id                                                 1600
# route_short_name                                          160
# route_long_name     Wainuiomata North - Waterloo - Lower Hutt
# route_type                                                  3
# start_time                                           05:48:00
# end_time                                             23:54:00
# num_trips                                                  78
# max_headway                                                37
# mean_trip_distance                                    18.9499
# mean_trip_duration                                   0.599359
# service_speed                                          31.617
#
#                                                       54                   32  \
# route_id                                            2800                 2040
# route_short_name                                     280                  204
# route_long_name     Waikanae - Waikanae Beach - Waikanae  Greytown - Woodside
# route_type                                             3                    3
# start_time                                      05:23:00             05:56:00
# end_time                                        21:50:00             19:55:00
# num_trips                                             30                   10
# max_headway                                           73                  308
# mean_trip_distance                               17.2168              11.3971
# mean_trip_duration                              0.463333                 0.26
# service_speed                                    37.1586              43.8349
#
#                                                             70  \
# route_id                                                     5
# route_short_name                                           HVL
# route_long_name     Hutt Valley Line (Upper Hutt - Wellington)
# route_type                                                   2
# start_time                                            04:30:00
# end_time                                              23:50:00
# num_trips                                                  111
# max_headway                                                 30
# mean_trip_distance                                     30.4569
# mean_trip_duration                                    0.685736
# service_speed                                           44.415
#
#                                              57  \
# route_id                                   2900
# route_short_name                            290
# route_long_name     Waikanae - Otaki - Waikanae
# route_type                                    3
# start_time                             06:26:00
# end_time                               19:18:00
# num_trips                                     9
# max_headway                                 147
# mean_trip_distance                      50.0839
# mean_trip_duration                      1.09074
# service_speed                           45.9173
#
#                                                      59  \
# route_id                                              3
# route_short_name                                    MEL
# route_long_name     Melling Line (Melling - Wellington)
# route_type                                            2
# start_time                                     06:14:00
# end_time                                       18:55:00
# num_trips                                            46
# max_headway                                          70
# mean_trip_distance                              14.1404
# mean_trip_duration                             0.299275
# service_speed                                   47.2486
#
#                                                                    28  \
# route_id                                                         2000
# route_short_name                                                  200
# route_long_name     Masterton - Greytown - Featherston - Martinbor...
# route_type                                                          3
# start_time                                                   05:55:00
# end_time                                                     19:50:00
# num_trips                                                          20
# max_headway                                                       170
# mean_trip_distance                                            40.5565
# mean_trip_duration                                           0.849167
# service_speed                                                 47.7604
#
#                                                          69  \
# route_id                                                  4
# route_short_name                                        WRL
# route_long_name     Wairarapa Line (Masterton - Wellington)
# route_type                                                2
# start_time                                         05:46:00
# end_time                                           20:03:00
# num_trips                                                10
# max_headway                                             308
# mean_trip_distance                                  90.9667
# mean_trip_duration                                  1.72667
# service_speed                                       52.6834
#
#                                                      25
# route_id                                              2
# route_short_name                                    KPL
# route_long_name     Kapiti Line (Waikanae - Wellington)
# route_type                                            2
# start_time                                     05:00:00
# end_time                                       24:14:00
# num_trips                                           117
# max_headway                                          30
# mean_trip_distance                               47.879
# mean_trip_duration                             0.865812
# service_speed                                   55.2995
#
# [11 rows x 85 columns]

# %%
# Map our extreme routes
feed.map_routes(route_ids=["9", "601", "4", "2"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Some open-source Python tools for public transport
#
# - [GTFSTK](https://github.com/mrcagney/gtfstk), library for analyzing GTFS feeds
# - [transitfeeds-api](https://github.com/fitnr/transitfeeds-api), Python wrapper for the transitfeeds.com API
# - [django-multi-gtfs](https://github.com/tulsawebdevs/django-multi-gtfs), Django app to import and export GTFS feeds
# - [partridge](https://github.com/remix/partridge), fast, forgiving Python GTFS reader built on Pandas DataFrames
# - [peartree](https://github.com/kuanb/peartree), library for converting transit data into a directed graph for network analysis
# - And more at the Github repository [awesome-transit](https://github.com/CUTR-at-USF/awesome-transit)
